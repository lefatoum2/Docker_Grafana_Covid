# %%
import pandas as pd

data1 = pd.read_csv('country_vaccinations.csv')
data1
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0      Albania      ALB  2021-01-10                 0.0                0.0
# 1      Albania      ALB  2021-01-11                 NaN                NaN
# 2      Albania      ALB  2021-01-12               128.0              128.0
# 3      Albania      ALB  2021-01-13               188.0              188.0
# 4      Albania      ALB  2021-01-14               266.0              266.0
# ...        ...      ...         ...                 ...                ...
# 4141  Zimbabwe      ZWE  2021-02-20                 NaN                NaN
# 4142  Zimbabwe      ZWE  2021-02-21                 NaN                NaN
# 4143  Zimbabwe      ZWE  2021-02-22              1314.0             1314.0
# 4144  Zimbabwe      ZWE  2021-02-23              4041.0             4041.0
# 4145  Zimbabwe      ZWE  2021-02-24              7872.0             7872.0
#
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4146 entries, 0 to 4145
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              4146 non-null   object
#  1   iso_code                             3854 non-null   object
#  2   date                                 4146 non-null   object
#  3   total_vaccinations                   2719 non-null   float64
#  4   people_vaccinated                    2307 non-null   float64
#  5   people_fully_vaccinated              1531 non-null   float64
#  6   daily_vaccinations_raw               2296 non-null   float64
#  7   daily_vaccinations                   3997 non-null   float64
#  8   total_vaccinations_per_hundred       2719 non-null   float64
#  9   people_vaccinated_per_hundred        2307 non-null   float64
#  10  people_fully_vaccinated_per_hundred  1531 non-null   float64
# ...

# %%
data1.isnull().sum()
# Out:
# country                                   0
# iso_code                                292
# date                                      0
# total_vaccinations                     1427
# people_vaccinated                      1839
# people_fully_vaccinated                2615
# daily_vaccinations_raw                 1850
# daily_vaccinations                      149
# total_vaccinations_per_hundred         1427
# people_vaccinated_per_hundred          1839
# people_fully_vaccinated_per_hundred    2615
# daily_vaccinations_per_million          149
# vaccines                                  0
# source_name                               0
# source_website                            0
# dtype: int64

# %%
data1['date'] = pd.to_datetime(data1['date'])

# %%
data2 = data1.dropna()

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1206 entries, 39 to 4065
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              1206 non-null   object
#  1   iso_code                             1206 non-null   object
#  2   date                                 1206 non-null   datetime64[ns]
#  3   total_vaccinations                   1206 non-null   float64
#  4   people_vaccinated                    1206 non-null   float64
#  5   people_fully_vaccinated              1206 non-null   float64
#  6   daily_vaccinations_raw               1206 non-null   float64
#  7   daily_vaccinations                   1206 non-null   float64
#  8   total_vaccinations_per_hundred       1206 non-null   float64
#  9   people_vaccinated_per_hundred        1206 non-null   float64
#  10  people_fully_vaccinated_per_hundred  1206 non-null   float64
# ...

# %%
data2
# Out:
#             country iso_code       date  total_vaccinations  \
# 127       Argentina      ARG 2021-01-25            292386.0
# 128       Argentina      ARG 2021-01-26            305880.0
# 129       Argentina      ARG 2021-01-27            318033.0
# 130       Argentina      ARG 2021-01-28            327999.0
# 131       Argentina      ARG 2021-01-29            344034.0
# ...             ...      ...        ...                 ...
# 4061  United States      USA 2021-02-20          61289500.0
# 4062  United States      USA 2021-02-21          63090634.0
# 4063  United States      USA 2021-02-22          64177474.0
# 4064  United States      USA 2021-02-23          65032083.0
# 4065  United States      USA 2021-02-24          66464947.0
#
#       people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 127            260122.0                  32264.0                   363.0
# 128            266969.0                  38911.0                 13494.0
# ...

# %%
data2.to_csv('country_vaccinations3.csv')
